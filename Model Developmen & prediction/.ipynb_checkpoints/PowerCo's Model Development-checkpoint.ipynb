# %% [markdown]
# # Modelling

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df=pd.read_csv("churn_data.csv")

# %%
df.head()
# Out:
#                                  id  cons_12m  cons_gas_12m  cons_last_month  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  0.000000     10.914124         0.000000
# 1  d29c2c54acc38ff3c0614d0a653813dd  8.446985      0.000000         0.000000
# 2  764c75f661154dac3a6c254cd082ea7d  6.300786      0.000000         0.000000
# 3  bba03439a292a1e166f80264c16191cb  7.368340      0.000000         0.000000
# 4  149d57cf92fc41cf94415803a877cb4b  8.395252      0.000000         6.267201
#
#    forecast_cons_12m  forecast_cons_year  forecast_discount_energy  \
# 0           0.000000            0.000000                       0.0
# 1           5.252012            0.000000                       0.0
# 2           3.891004            0.000000                       0.0
# 3           5.484963            0.000000                       0.0
# 4           6.101999            6.267201                       0.0
#
#    forecast_meter_rent_12m  forecast_price_energy_off_peak  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   cons_12m                        14606 non-null  float64
#  2   cons_gas_12m                    14606 non-null  float64
#  3   cons_last_month                 14606 non-null  float64
#  4   forecast_cons_12m               14606 non-null  float64
#  5   forecast_cons_year              14606 non-null  float64
#  6   forecast_discount_energy        14606 non-null  float64
#  7   forecast_meter_rent_12m         14606 non-null  float64
#  8   forecast_price_energy_off_peak  14606 non-null  float64
#  9   forecast_price_energy_peak      14606 non-null  float64
#  10  forecast_price_pow_off_peak     14606 non-null  float64
#  11  imp_cons                        14606 non-null  float64
# ...

# %% [markdown]
# ## Split the data

# %%
# Separate target variable from independent variables
X = df.drop(columns=['id', 'churn'])
y = df['churn']

# %%
from sklearn.model_selection import train_test_split

# Split data 70%-30% into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

print ('Training cases: %d\nTest cases: %d' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training cases: 11684
# Test cases: 2922

# %% [markdown]
# ## Rectify the class Imbalancs

# %%
from imblearn.over_sampling import SMOTE
X, y = SMOTE().fit_resample(X, y)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11684, 30)
# (11684,)
# (2922, 30)
# (2922,)

# %% [markdown]
# ## Modeling

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9195756331279945

# %%
# Precision, Recall, F1
precision = precision_score(y_test, y_pred, average='macro')  # use 'binary' for binary classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.8885852169202737
# Recall: 0.5354386227544911
# F1 Score: 0.5453368673288383

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid", font_scale=1.2)  # Clean background and proper font scaling

sns.heatmap(
    cm, 
    annot=True,  # Annotate with actual counts
    fmt='d',     # Display as integers
    cmap='Blues',  # Color palette
    cbar=False,  # Disable color bar for simplicity
    annot_kws={"size": 14, 'weight': 'bold'},  # Font properties for annotations
    linewidths=0.5,  # Thin lines for grid separation
    linecolor='gray'  # Gridline color
)

plt.title('Confusion Matrix', fontsize=18, weight='bold')
plt.xlabel('Predicted Labels', fontsize=14, weight='bold')
plt.ylabel('True Labels', fontsize=14, weight='bold')

plt.xticks(ticks=[0.5, 1.5], labels=['Class 0', 'Class 1'], fontsize=12, rotation=0)
plt.yticks(ticks=[0.5, 1.5], labels=['Class 0', 'Class 1'], fontsize=12, rotation=0)

plt.tight_layout()

plt.show()

# %%
# Full report
report = classification_report(y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2672
#            1       0.86      0.07      0.13       250
#
#     accuracy                           0.92      2922
#    macro avg       0.89      0.54      0.55      2922
# weighted avg       0.91      0.92      0.89      2922

# %% [markdown]
# ## Prediction Comparison

# %%
comparison_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

# %%
comparison_df.sample(20)
# Out:
#        Actual  Predicted
# 11266       0          0
# 1387        0          0
# 4221        0          0
# 14262       0          0
# 8624        0          0
# 14345       1          0
# 9944        0          0
# 5111        0          0
# 11262       0          0
# 9649        0          0
# 10069       0          0
# 2697        1          1
# 8023        0          0
# 9608        1          0
# 304         0          0
# 11134       0          0
# 6757        0          0
# 190         0          0
# 10828       0          0
# 4991        0          0

# %% [markdown]
# ### Feature Importances

# %%
feat_imp_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=True).reset_index()

# %%
plt.figure(figsize=(10, 8))
sns.set(style="whitegrid")  # Clean background
sns.barplot(
    x="Importance",
    y="Feature",
    data=feat_imp_df,
    palette="viridis"
)

plt.title("Top 20 Feature Importances", fontsize=16, weight='bold')
plt.xlabel("Relative Importance", fontsize=12)
plt.ylabel("Feature", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# 👆 Based on the output of the feature importances, `price sensitivity` it is not a main driver but it is a weak contributor.
#
# It conflicts with the findings from the earlier investigation conducted during the `EDA` phase. To reach a definitive conclusion, further experimentation is required.
